# %% [markdown]
# # Clasificación por vecinos más cercanos
#
# Para este punto, se usan los datos del fichero penguins.csv que se encuentra en el repositorio de datos de seaborn, en los cuales se encuentran los datos de alturas, anchuras y masas de pinguinos, y su especie. El primer paso es definir las funciones necesarias, entre las cuales se crearon las funciones normalizar_cols y normalizar_total para normalizar los datos, la función euclidiana n-dimensional para calcular la distancia euclidiana entre dos puntos, y la función knn para calcular la clasificación por vecinos más cercanos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def normalizar_cols(df, cols):
    for i in cols:
        try:
            max_i = df[i].max()
            min_i = df[i].min()
            df[i] = (df[i] - min_i) / (max_i - min_i)
        except Exception:
            pass
    return df

def normalizar_total(df, cols):
    max_i = df[cols].max().max()
    min_i = df[cols].min().min()
    df[cols] = (df[cols] - min_i) / (max_i - min_i)
    return df

def euclidiana(x0, x1):
    suma = 0
    for i in zip(x0, x1):
        suma += (i[0] - i[1]) ** 2
    return np.sqrt(suma)

def knn(df, k_punto, ejes, categoria, vecinos=5):
    """
    Calcula los K vecinos más cercanos y retorna la categoría más frecuente.
    """
    df_parcial = df[ejes + [categoria]].copy()
    df_parcial['distancia'] = df_parcial.apply(lambda x: euclidiana(x[ejes], k_punto), axis=1)
    df_parcial = df_parcial.sort_values(by='distancia')
    df_parcial = df_parcial.head(vecinos)
    frecuencias = df_parcial[categoria].value_counts()
    return frecuencias.index[0]

# %% [markdown]
# ## Carga de datos

# %%
df = sns.load_dataset('penguins').dropna()
df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %% [markdown]
# ### Selección de datos
#
# Se seleccionan los datos de pinguinos para este ejemplo, los cuales van a ser clasificados por especie, se divide el dataset en un 80% para entrenamiento y 20% para pruebas, y se normalizan las columnas de interés por columnas, de esta forma el peso de cada variable es equivalente.

# %%
categorias=df['species'].unique()
categoria_col='species'
cols_3d=['bill_length_mm', 'bill_depth_mm', 'body_mass_g']

df=normalizar_cols(df, cols_3d)

train = df.sample(frac=0.8)
test = df.drop(train.index)

colores ={}
colores_name=['red','green','blue']
for i in categorias:
    colores[i]=colores_name.pop()

# %% [markdown]
# ### Evaluación de la predicción
# Debido a la separación de los datos, los grupos formados son muy discriminados, esto facilita la clasificación, y permite tener un alto nivel de acertividad en la predicción.

# %%
test['predicho']=test[cols_3d].apply(lambda x: knn(train, x, cols_3d, categoria_col, vecinos=7), axis=1)

cm = pd.crosstab(test[categoria_col], test['predicho'])
cm
# Out:
# predicho   Adelie  Chinstrap  Gentoo
# species
# Adelie         27          0       0
# Chinstrap       0         20       0
# Gentoo          0          0      20

# %%
test[test['predicho']!=test['species']]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, predicho]
# Index: []

# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in ./Jupyter_lab/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: ipython<10 in ./Jupyter_lab/lib/python3.12/site-packages (from ipympl) (9.10.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in ./Jupyter_lab/lib/python3.12/site-packages (from ipympl) (8.1.8)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in ./Jupyter_lab/lib/python3.12/site-packages (from ipympl) (3.10.8)
# Requirement already satisfied: numpy in ./Jupyter_lab/lib/python3.12/site-packages (from ipympl) (2.4.2)
# Requirement already satisfied: pillow in ./Jupyter_lab/lib/python3.12/site-packages (from ipympl) (12.1.1)
# Requirement already satisfied: traitlets<6 in ./Jupyter_lab/lib/python3.12/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in ./Jupyter_lab/lib/python3.12/site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in ./Jupyter_lab/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./Jupyter_lab/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./Jupyter_lab/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in ./Jupyter_lab/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./Jupyter_lab/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./Jupyter_lab/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./Jupyter_lab/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./Jupyter_lab/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (26.0)
# Requirement already satisfied: pyparsing>=3 in ./Jupyter_lab/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./Jupyter_lab/lib/python3.12/site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in ./Jupyter_lab/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./Jupyter_lab/lib/python3.12/site-packages (from jedi>=0.18.1->ipython<10->ipympl) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in ./Jupyter_lab/lib/python3.12/site-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./Jupyter_lab/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./Jupyter_lab/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./Jupyter_lab/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (3.0.1)
# Requirement already satisfied: pure-eval in ./Jupyter_lab/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (0.2.3)

# %% [markdown]
# ### Presentación
# Como ultimo paso, se presentan los resultados del algoritmo KNN, en un grafico 3D, con el cual se puede interactuar al usar el elemento **%matplotlib widget**

# %%
# %matplotlib widget
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(projection='3d')
for cat in categorias:
    color = colores.get(cat, 'gray')  # Color gris por defecto si hay más categorías
    
    # Filtrar puntos de esta categoría
    df_orig = train[train[categoria_col] == cat]
    df_pred = test[test['predicho'] == cat]
    
    # Puntos iniciales: forma de círculo ('o'), menor opacidad para no saturar
    ax.scatter(df_orig[cols_3d[0]], df_orig[cols_3d[1]], df_orig[cols_3d[2]], 
                color=color, marker='o', s=40, alpha=0.3, 
                label=f'Inicial - Cat {cat}')
    
    if not df_pred.empty:
        df_pred_corr=df_pred[df_pred['predicho']==df_pred['species']]
        df_pred_incorr=df_pred[df_pred['predicho']!=df_pred['species']]
        if not df_pred_corr.empty:
            ax.scatter(df_pred_corr[cols_3d[0]], df_pred_corr[cols_3d[1]], df_pred_corr[cols_3d[2]], 
                        color=color, marker='^', s=120, alpha=1.0, edgecolor='black', 
                        label=f'Predicho - Cat {cat}')
        if not df_pred_incorr.empty:
            ax.scatter(df_pred_incorr[cols_3d[0]], df_pred_incorr[cols_3d[1]], df_pred_incorr[cols_3d[2]], 
                        color=color, marker='x', s=120, alpha=1.0, edgecolor='black', 
                        label=f'Predicho - Cat {cat}')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
